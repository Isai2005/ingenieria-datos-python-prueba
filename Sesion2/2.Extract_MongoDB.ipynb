# %%
import pandas as pd

# %%
! python -m pip install "pymongo[srv]"
# Out:
# ...
# WARNING: pymongo 4.15.5 does not provide the extra 'srv'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 11.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pymongo]m1/2 [pymongo]
# ...

# %%
# Aqui hacemos la autotenticacion    el mongodb

from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://230300977_db_user:kz5QC2cv3gy3bDZ@cluster0.e1iz92h.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# Asi nos conectamos a la base de datos de mongo

db_mflix = client['sample_mflix']

# %%
# Como obtenemos datos, como consultamos?

collection_users = db_mflix['users']

users = collection_users.find({})

df_users = pd.DataFrame(users)

df_users
# Out:
#                           _id                      name  \
# 0    59b99db4cfa9a34dcd7885b6                 Ned Stark
# 1    59b99db4cfa9a34dcd7885b7          Robert Baratheon
# 2    59b99db5cfa9a34dcd7885b8           Jaime Lannister
# 3    59b99db5cfa9a34dcd7885b9             Catelyn Stark
# 4    59b99db6cfa9a34dcd7885ba          Cersei Lannister
# ..                        ...                       ...
# 180  59b99e08cfa9a34dcd78866a           Shawn Mccormick
# 181  59b99e09cfa9a34dcd78866b             Anthony Hurst
# 182  59b99e09cfa9a34dcd78866c               Ashlee Hart
# 183  5db1c37e4a68c31f10cf0a98  Magical Mr. Mistoffelees
# 184  5db1c37e4a68c31f10cf0a9f                       foo
#
#                                     email  \
# 0                sean_bean@gameofthron.es
# 1                mark_addy@gameofthron.es
# 2    nikolaj_coster-waldau@gameofthron.es
# 3         michelle_fairley@gameofthron.es
# 4              lena_headey@gameofthron.es
# ...

# %%
# Practica de conexion a la base de datos theaters

prueba_conexion = db_mflix['theaters']

theaters = prueba_conexion.find({})

df_theaters = pd.DataFrame(theaters)

df_theaters
# Out:
#                            _id  theaterId  \
# 0     59a47286cfa9a3a73e51e72c       1000
# 1     59a47286cfa9a3a73e51e72d       1003
# 2     59a47286cfa9a3a73e51e72e       1008
# 3     59a47286cfa9a3a73e51e72f       1004
# 4     59a47286cfa9a3a73e51e730       1002
# ...                        ...        ...
# 1559  59a47287cfa9a3a73e51ed43        940
# 1560  59a47287cfa9a3a73e51ed44        951
# 1561  59a47287cfa9a3a73e51ed45        949
# 1562  59a47287cfa9a3a73e51ed46        952
# 1563  59a47287cfa9a3a73e51ed47        953
#
#                                                location
# 0     {'address': {'street1': '340 W Market', 'city'...
# 1     {'address': {'street1': '45235 Worth Ave.', 'c...
# 2     {'address': {'street1': '1621 E Monte Vista Av...
# 3     {'address': {'street1': '5072 Pinnacle Sq', 'c...
# 4     {'address': {'street1': '1900 E Rio Salado Pkw...
# ...                                                 ...
# 1559  {'address': {'street1': '4310 Buffalo Gap Rd',...
# ...
