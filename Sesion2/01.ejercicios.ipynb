# %%
import random

# %%
lista = [random.randint(0,100) for i in range(0,100)]
print(lista)
# Out:
# [24, 79, 28, 40, 19, 34, 57, 45, 4, 50, 14, 32, 37, 59, 31, 6, 50, 54, 47, 88, 9, 89, 76, 85, 18, 74, 2, 19, 32, 52, 12, 88, 24, 20, 30, 76, 67, 12, 19, 67, 78, 43, 52, 98, 52, 7, 72, 52, 46, 71, 79, 36, 36, 70, 95, 63, 95, 23, 8, 19, 47, 46, 91, 52, 70, 61, 20, 9, 59, 70, 28, 18, 36, 10, 74, 13, 40, 74, 85, 39, 5, 100, 95, 50, 13, 49, 12, 65, 42, 14, 8, 32, 15, 90, 80, 6, 5, 59, 25, 61]

# %%
# funcion para sumar numeros pares usamos el operador %, para que sea par al dividirlo no tiene que sobrar nada
def suma_pares(lista):
    sum = 0
    for item in lista:
        if item % 2 == 0:
           sum = sum + item  
    return sum

print(suma_pares(lista))
# Out:
# 2512

# %%
# funcion para buscar un elemento en una lista
def buscar_elemento(lista, elemento):
    for item in lista:
        if item == elemento:
            return True
    return False 

print(buscar_elemento(lista,4))
# Out:
# True

# %%
# Crear una función que reciba una lista de palabras y retorne un diccionario con 
# la cantidad de veces que aparece cada palabra.
def contar_palabras(lista):
    dict_frec = {}
    for palabra in lista:
        if palabra in dict_frec:
            dict_frec[palabra] = dict_frec[palabra] + 1
        else:
            dict_frec[palabra] = 1
            
    return dict_frec

palabras = ["python", "java", "python", "c++", "python", "java"]
resultado = contar_palabras(palabras)
print(resultado)
# Out:
# {'python': 3, 'java': 2, 'c++': 1}

# %%
# Crear una función que reciba un diccionario donde las llaves sean nombres y los valores sean notas.
# Debe retornar el nombre del alumno con la nota más alta
def mejor_alumno(diccionario):
    nombre = ''
    nota_aux = -1
    for nombre_dict, nota in diccionario.items():
        if nota > nota_aux:
            nota_aux = nota 
            nombre = nombre_dict
    return nombre 
                                        

notas = {"Ana": 15, "Luis": 18, "María": 17, "Pedro": 19}
print(mejor_alumno(notas))
# Out:
# Pedro
